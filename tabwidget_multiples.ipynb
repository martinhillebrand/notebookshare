# %% [markdown]
# # function

# %%
from IPython.core.display import display, HTML
import teradataml as tdml
import uuid  

def display_dataframes_as_html_tabs(table_names):
    unique_id = str(uuid.uuid4()).replace("-", "")  # Unique identifier for this tab instance

    html_code = f"""
    <style>
        .tab-container-{unique_id} {{
            border-bottom: 2px solid #ddd;
            display: flex;
        }}
        .tab-label-{unique_id} {{
            padding: 10px 15px;
            cursor: pointer;
            border: 1px solid #ddd;
            border-bottom: none;
            background: #f1f1f1;
            margin-right: 5px;
        }}
        .tab-label-{unique_id}.active {{
            background: white;
            border-top: 2px solid #007bff;
            font-weight: bold;
        }}
        .tab-content-{unique_id} {{
            display: none;
            padding: 15px;
            border: 1px solid #ddd;
            text-align: left;
        }}
        .tab-content-{unique_id}.active {{
            display: block;
        }}
    </style>
    
    <div class="tab-container-{unique_id}">
    """

    # Generate tab headers with unique per-tab IDs
    tab_ids = []  
    for i, table_name in enumerate(table_names):
        tab_id = str(uuid.uuid4()).replace("-", "")  # Unique ID for each tab
        tab_ids.append(tab_id)
        active_class = "active" if i == 0 else ""
        html_code += f'<div class="tab-label-{unique_id} {active_class}" data-tab="{tab_id}">{table_name}</div>'

    html_code += "</div>"

    # Generate tab content
    for i, (table_name, tab_id) in enumerate(zip(table_names, tab_ids)):
        df_head = tdml.DataFrame(table_name)
        df_html = df_head._repr_html_()
        display_style = "active" if i == 0 else ""
        html_code += f'<div class="tab-content-{unique_id} {display_style}" id="tab-{tab_id}">{df_html}</div>'

    # Global JavaScript to handle tab switching across multiple cell executions
    html_code += f"""
    <script>
        (function() {{
            // Handle tab switching functionality
            let tabs = document.querySelectorAll(".tab-label-{unique_id}");
            let contents = document.querySelectorAll(".tab-content-{unique_id}");
            
            tabs.forEach((tab) => {{
                tab.addEventListener("click", function() {{
                    // Remove active class from all tabs and contents
                    tabs.forEach(t => t.classList.remove("active"));
                    contents.forEach(c => c.classList.remove("active"));
                    
                    // Add active class to the clicked tab and corresponding content
                    let tabId = this.getAttribute("data-tab");
                    document.getElementById("tab-" + tabId).classList.add("active");
                    this.classList.add("active");
                }});
            }});
        }})();
    </script>
    """

    display(HTML(html_code))

# %% [markdown]
# # execution

# %%
display_dataframes_as_html_tabs(["t_a","t_b"])
# Out:
#     <style>
#         .tab-container-b0168f701d4a4bac88a0d13f5cb13487 {
#             border-bottom: 2px solid #ddd;
#             display: flex;
#         }
#         .tab-label-b0168f701d4a4bac88a0d13f5cb13487 {
#             padding: 10px 15px;
#             cursor: pointer;
#             border: 1px solid #ddd;
#             border-bottom: none;
#             background: #f1f1f1;
#             margin-right: 5px;
#         }
#         .tab-label-b0168f701d4a4bac88a0d13f5cb13487.active {
#             background: white;
#             border-top: 2px solid #007bff;
#             font-weight: bold;
#         }
#         .tab-content-b0168f701d4a4bac88a0d13f5cb13487 {
#             display: none;
#             padding: 15px;
#             border: 1px solid #ddd;
#             text-align: left;
#         }
#         .tab-content-b0168f701d4a4bac88a0d13f5cb13487.active {
#             display: block;
#         }
#     </style>
#
#     <div class="tab-container-b0168f701d4a4bac88a0d13f5cb13487">
#     <div class="tab-label-b0168f701d4a4bac88a0d13f5cb13487 active" data-tab="1568122cc11641018783086b816237ba">t_a</div><div class="tab-label-b0168f701d4a4bac88a0d13f5cb13487 " data-tab="e9ba3e08bff54911bb249262d3e9d6ca">t_b</div></div><div class="tab-content-b0168f701d4a4bac88a0d13f5cb13487 active" id="tab-1568122cc11641018783086b816237ba"><style type="text/css">
# 	table {border:ridge 5px;}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}</style>
# <html><table>
# 	<tr id="HeaderRow">
# 		<th>a1</th>
# 		<th>a2</th>
# 	</tr>
# 	<tr>
# 		<td>GDSG</td>
# 		<td>42D</td>
# 	</tr>
# 	<tr>
# 		<td>sgdgsd</td>
# 		<td>F33</td>
# 	</tr>
# </table></html></div><div class="tab-content-b0168f701d4a4bac88a0d13f5cb13487 " id="tab-e9ba3e08bff54911bb249262d3e9d6ca"><style type="text/css">
# 	table {border:ridge 5px;}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}</style>
# <html><table>
# 	<tr id="HeaderRow">
# 		<th>b1</th>
# 		<th>b2</th>
# 	</tr>
# 	<tr>
# 		<td>hth</td>
# 		<td>u46jrjrt</td>
# 	</tr>
# 	<tr>
# 		<td>43</td>
# 		<td>rerh</td>
# 	</tr>
# </table></html></div>
#     <script>
#         (function() {
#             // Handle tab switching functionality
#             let tabs = document.querySelectorAll(".tab-label-b0168f701d4a4bac88a0d13f5cb13487");
#             let contents = document.querySelectorAll(".tab-content-b0168f701d4a4bac88a0d13f5cb13487");
#
#             tabs.forEach((tab) => {
#                 tab.addEventListener("click", function() {
#                     // Remove active class from all tabs and contents
#                     tabs.forEach(t => t.classList.remove("active"));
#                     contents.forEach(c => c.classList.remove("active"));
#
#                     // Add active class to the clicked tab and corresponding content
#                     let tabId = this.getAttribute("data-tab");
#                     document.getElementById("tab-" + tabId).classList.add("active");
#                     this.classList.add("active");
#                 });
#             });
#         })();
#     </script>

# %%
display_dataframes_as_html_tabs(["t_c","t_d"])
# Out:
#     <style>
#         .tab-container-36456817d3bb4d6091ea889cb3ab134d {
#             border-bottom: 2px solid #ddd;
#             display: flex;
#         }
#         .tab-label-36456817d3bb4d6091ea889cb3ab134d {
#             padding: 10px 15px;
#             cursor: pointer;
#             border: 1px solid #ddd;
#             border-bottom: none;
#             background: #f1f1f1;
#             margin-right: 5px;
#         }
#         .tab-label-36456817d3bb4d6091ea889cb3ab134d.active {
#             background: white;
#             border-top: 2px solid #007bff;
#             font-weight: bold;
#         }
#         .tab-content-36456817d3bb4d6091ea889cb3ab134d {
#             display: none;
#             padding: 15px;
#             border: 1px solid #ddd;
#             text-align: left;
#         }
#         .tab-content-36456817d3bb4d6091ea889cb3ab134d.active {
#             display: block;
#         }
#     </style>
#
#     <div class="tab-container-36456817d3bb4d6091ea889cb3ab134d">
#     <div class="tab-label-36456817d3bb4d6091ea889cb3ab134d active" data-tab="2f8c8ae9a0b34ab3a5083913d98221c2">t_c</div><div class="tab-label-36456817d3bb4d6091ea889cb3ab134d " data-tab="6d6c486b427d4d269ce045d8eff95ecc">t_d</div></div><div class="tab-content-36456817d3bb4d6091ea889cb3ab134d active" id="tab-2f8c8ae9a0b34ab3a5083913d98221c2"><style type="text/css">
# 	table {border:ridge 5px;}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}</style>
# <html><table>
# 	<tr id="HeaderRow">
# 		<th>c1</th>
# 		<th>c2</th>
# 	</tr>
# 	<tr>
# 		<td>hetr</td>
# 		<td>htrehrtjjrt</td>
# 	</tr>
# 	<tr>
# 		<td>eheh</td>
# 		<td>h5hf</td>
# 	</tr>
# </table></html></div><div class="tab-content-36456817d3bb4d6091ea889cb3ab134d " id="tab-6d6c486b427d4d269ce045d8eff95ecc"><style type="text/css">
# 	table {border:ridge 5px;}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}</style>
# <html><table>
# 	<tr id="HeaderRow">
# 		<th>d1</th>
# 		<th>d2</th>
# 	</tr>
# 	<tr>
# 		<td>th</td>
# 		<td>55rrhe</td>
# 	</tr>
# 	<tr>
# 		<td>htt</td>
# 		<td>heh</td>
# 	</tr>
# </table></html></div>
#     <script>
#         (function() {
#             // Handle tab switching functionality
#             let tabs = document.querySelectorAll(".tab-label-36456817d3bb4d6091ea889cb3ab134d");
#             let contents = document.querySelectorAll(".tab-content-36456817d3bb4d6091ea889cb3ab134d");
#
#             tabs.forEach((tab) => {
#                 tab.addEventListener("click", function() {
#                     // Remove active class from all tabs and contents
#                     tabs.forEach(t => t.classList.remove("active"));
#                     contents.forEach(c => c.classList.remove("active"));
#
#                     // Add active class to the clicked tab and corresponding content
#                     let tabId = this.getAttribute("data-tab");
#                     document.getElementById("tab-" + tabId).classList.add("active");
#                     this.classList.add("active");
#                 });
#             });
#         })();
#     </script>

# %%
display_dataframes_as_html_tabs(["t_a","t_d"])
# Out:
#     <style>
#         .tab-container-96a5f82826ab497299a7cfec37a3d04e {
#             border-bottom: 2px solid #ddd;
#             display: flex;
#         }
#         .tab-label-96a5f82826ab497299a7cfec37a3d04e {
#             padding: 10px 15px;
#             cursor: pointer;
#             border: 1px solid #ddd;
#             border-bottom: none;
#             background: #f1f1f1;
#             margin-right: 5px;
#         }
#         .tab-label-96a5f82826ab497299a7cfec37a3d04e.active {
#             background: white;
#             border-top: 2px solid #007bff;
#             font-weight: bold;
#         }
#         .tab-content-96a5f82826ab497299a7cfec37a3d04e {
#             display: none;
#             padding: 15px;
#             border: 1px solid #ddd;
#             text-align: left;
#         }
#         .tab-content-96a5f82826ab497299a7cfec37a3d04e.active {
#             display: block;
#         }
#     </style>
#
#     <div class="tab-container-96a5f82826ab497299a7cfec37a3d04e">
#     <div class="tab-label-96a5f82826ab497299a7cfec37a3d04e active" data-tab="8964d98fef6a4c0193f2567011838575">t_a</div><div class="tab-label-96a5f82826ab497299a7cfec37a3d04e " data-tab="10c4d1ccd56c4b558e25c636598eece8">t_d</div></div><div class="tab-content-96a5f82826ab497299a7cfec37a3d04e active" id="tab-8964d98fef6a4c0193f2567011838575"><style type="text/css">
# 	table {border:ridge 5px;}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}</style>
# <html><table>
# 	<tr id="HeaderRow">
# 		<th>a1</th>
# 		<th>a2</th>
# 	</tr>
# 	<tr>
# 		<td>GDSG</td>
# 		<td>42D</td>
# 	</tr>
# 	<tr>
# 		<td>sgdgsd</td>
# 		<td>F33</td>
# 	</tr>
# </table></html></div><div class="tab-content-96a5f82826ab497299a7cfec37a3d04e " id="tab-10c4d1ccd56c4b558e25c636598eece8"><style type="text/css">
# 	table {border:ridge 5px;}
# 	table td {border:inset 1px;}
# 	table tr#HeaderRow {background-color:grey; color:white;}</style>
# <html><table>
# 	<tr id="HeaderRow">
# 		<th>d1</th>
# 		<th>d2</th>
# 	</tr>
# 	<tr>
# 		<td>th</td>
# 		<td>55rrhe</td>
# 	</tr>
# 	<tr>
# 		<td>htt</td>
# 		<td>heh</td>
# 	</tr>
# </table></html></div>
#     <script>
#         (function() {
#             // Handle tab switching functionality
#             let tabs = document.querySelectorAll(".tab-label-96a5f82826ab497299a7cfec37a3d04e");
#             let contents = document.querySelectorAll(".tab-content-96a5f82826ab497299a7cfec37a3d04e");
#
#             tabs.forEach((tab) => {
#                 tab.addEventListener("click", function() {
#                     // Remove active class from all tabs and contents
#                     tabs.forEach(t => t.classList.remove("active"));
#                     contents.forEach(c => c.classList.remove("active"));
#
#                     // Add active class to the clicked tab and corresponding content
#                     let tabId = this.getAttribute("data-tab");
#                     document.getElementById("tab-" + tabId).classList.add("active");
#                     this.classList.add("active");
#                 });
#             });
#         })();
#     </script>
